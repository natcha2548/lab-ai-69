# %% [markdown]
# <a href="https://colab.research.google.com/github/natcha2548/lab-ai-69/blob/main/Lab-ai_Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 8.0
lr = 0.1                      # ขนาดก้าว

for i in range(21):
    if i in (0, 1, 2, 3, 5, 10, 20):
        print(f"ก้าว {i:2d}  x = {x:7.4f}  ความสูง = {x*x:8.4f}")
    gradient = 2*x            # ความชันใต้ฝ่าเท้า
    x = x - lr*gradient       # ก้าวสวนทางความชัน
# Out:
# ก้าว  0  x =  8.0000  ความสูง =  64.0000
# ก้าว  1  x =  6.4000  ความสูง =  40.9600
# ก้าว  2  x =  5.1200  ความสูง =  26.2144
# ก้าว  3  x =  4.0960  ความสูง =  16.7772
# ก้าว  5  x =  2.6214  ความสูง =   6.8719
# ก้าว 10  x =  0.8590  ความสูง =   0.7379
# ก้าว 20  x =  0.0922  ความสูง =   0.0085

# %%
for lr in [0.01, 0.1, 0.45, 0.55, 1.05]:
    x = 8.0
    for _ in range(20):
        x = x - lr*2*x
    print(f"lr {lr:5.2f}  หลัง 20 ก้าว x = {x:.4f}")
# Out:
# lr  0.01  หลัง 20 ก้าว x = 5.3409
# lr  0.10  หลัง 20 ก้าว x = 0.0922
# lr  0.45  หลัง 20 ก้าว x = 0.0000
# lr  0.55  หลัง 20 ก้าว x = 0.0000
# lr  1.05  หลัง 20 ก้าว x = 53.8200

# %%
def trace_gradient_descent(lr, steps=10):
    x = 8.0
    print(f'--- Tracking lr = {lr} ---')
    for i in range(steps + 1):
        print(f'Step {i:2d}: x = {x:10.4f}, |x| = {abs(x):10.4f}')
        gradient = 2 * x
        x = x - lr * gradient

trace_gradient_descent(0.55)
print()
trace_gradient_descent(1.05)
# Out:
# --- Tracking lr = 0.55 ---
# Step  0: x =     8.0000, |x| =     8.0000
# Step  1: x =    -0.8000, |x| =     0.8000
# Step  2: x =     0.0800, |x| =     0.0800
# Step  3: x =    -0.0080, |x| =     0.0080
# Step  4: x =     0.0008, |x| =     0.0008
# Step  5: x =    -0.0001, |x| =     0.0001
# Step  6: x =     0.0000, |x| =     0.0000
# Step  7: x =    -0.0000, |x| =     0.0000
# Step  8: x =     0.0000, |x| =     0.0000
# Step  9: x =    -0.0000, |x| =     0.0000
# Step 10: x =     0.0000, |x| =     0.0000
#
# --- Tracking lr = 1.05 ---
# Step  0: x =     8.0000, |x| =     8.0000
# Step  1: x =    -8.8000, |x| =     8.8000
# Step  2: x =     9.6800, |x| =     9.6800
# Step  3: x =   -10.6480, |x| =    10.6480
# Step  4: x =    11.7128, |x| =    11.7128
# Step  5: x =   -12.8841, |x| =    12.8841
# Step  6: x =    14.1725, |x| =    14.1725
# Step  7: x =   -15.5897, |x| =    15.5897
# Step  8: x =    17.1487, |x| =    17.1487
# Step  9: x =   -18.8636, |x| =    18.8636
# Step 10: x =    20.7499, |x| =    20.7499

# %% [markdown]
# ### คำอธิบาย: ทำไม 0.55 ถึงรอด แต่ 1.05 ถึงพัง?
#
# หัวใจสำคัญอยู่ที่การพิจารณาสมการการอัปเดต:
# $x_{new} = x_{old} - lr \cdot (2x_{old}) = x_{old}(1 - 2lr)$
#
# ตัวคูณที่จะกำหนดชะตากรรมของ $x$ คือ **$(1 - 2lr)$** ครับ
#
# 1.  **กรณี lr = 0.55:**
#     *   ตัวคูณคือ $(1 - 2 \times 0.55) = -0.1$
#     *   การคูณด้วย -0.1 ทำให้เครื่องหมายสลับกัน (บวกเป็นลบ ลบเป็นบวก) **แต่** ขนาดของ $x$ จะ **ลดลงเหลือเพียง 10%** ของค่าเดิมในทุกๆ ก้าว (หดลงเรื่อยๆ)
#     *   เมื่อขนาดหดลงเรื่อยๆ สุดท้าย $x$ จึงลู่เข้าหา 0 (ก้นหุบ) ได้สำเร็จ
#
# 2.  **กรณี lr = 1.05:**
#     *   ตัวคูณคือ $(1 - 2 \times 1.05) = -1.1$
#     *   การคูณด้วย -1.1 ทำให้เครื่องหมายสลับกันเช่นกัน **แต่** ขนาดของ $x$ จะ **เพิ่มขึ้นเป็น 1.1 เท่า (โตขึ้น 10%)** ในทุกๆ ก้าว
#     *   ยิ่งก้าวยิ่งกระโดดไกลออกไปเรื่อยๆ จนกู่ไม่กลับ (Diverge) นั่นเองครับ
#
# **สรุป:** ถ้า $|1 - 2lr| < 1$ มันจะค่อยๆ หดเข้าหาจุดศูนย์กลาง แต่ถ้า $|1 - 2lr| > 1$ มันจะระเบิดออกครับ!

# %%
import numpy as np

rng = np.random.default_rng(1)
X = np.array([[0,0],[0,1],[1,0],[1,1]], float)
y = np.array([[0],[1],[1],[0]], float)

# %%
X
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]])

# %%
y
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        [0.]])

# %%
W1 = rng.normal(0, 1, (2,2)); b1 = np.zeros((1,2))
W2 = rng.normal(0, 1, (2,1)); b2 = np.zeros((1,1))
sig = lambda z: 1/(1+np.exp(-z))

# %%
W1
# Out:
# array([[ 0.34558419,  0.82161814],
#        [ 0.33043708, -1.30315723]])

# %%
W2
# Out:
# array([[0.90535587],
#        [0.44637457]])

# %%
sig
# Out:
# <function __main__.<lambda>(z)>

# %%
h = sig(X@W1 + b1)            # ชั้นซ่อนคิด
out = sig(h@W2 + b2)          # ชั้นตอบคิด
print("คำตอบก่อนฝึก", np.round(out.ravel(), 3))
print("loss ก่อนฝึก", round(float(np.mean((out-y)**2)), 4))
# Out:
# คำตอบก่อนฝึก [0.663 0.651 0.699 0.684]
# loss ก่อนฝึก 0.2799

# %%
lr = 0.5
for epoch in range(20001):
    h = sig(X@W1 + b1)                  # จังหวะ 1 คิดไปข้างหน้า
    out = sig(h@W2 + b2)
    loss = np.mean((out-y)**2)          # จังหวะ 2 วัดความผิด
    if epoch in (0, 100, 1000, 5000, 20000):
        print(f"รอบ {epoch:5d}  loss = {loss:.4f}")

    d_out = (out-y)*out*(1-out)         # จังหวะ 3 ใบตำหนิชั้นตอบ
    d_h = d_out@W2.T * h*(1-h)          # ส่งย้อนไปชั้นซ่อน
    W2 -= lr*h.T@d_out; b2 -= lr*d_out.sum(0)
    W1 -= lr*X.T@d_h;  b1 -= lr*d_h.sum(0)

print("คำตอบหลังฝึก", np.round(out.ravel(), 3))
# Out:
# รอบ     0  loss = 0.2799
# รอบ   100  loss = 0.2486
# รอบ  1000  loss = 0.0155
# รอบ  5000  loss = 0.0007
# รอบ 20000  loss = 0.0001
# คำตอบหลังฝึก [0.013 0.989 0.989 0.011]

# %%
print(np.round(sig(X@W1 + b1), 2))
# Out:
# [[0.04 0.03]
#  [0.93 0.  ]
#  [0.   0.95]
#  [0.03 0.02]]

# %%
import torch
import torch.nn as nn

torch.manual_seed(1)
X = torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = torch.tensor([[0.],[1.],[1.],[0.]])

# %%
model = nn.Sequential(nn.Linear(2,2), nn.Sigmoid(),
                      nn.Linear(2,1), nn.Sigmoid())
opt = torch.optim.SGD(model.parameters(), lr=0.5)
loss_fn = nn.MSELoss()

# %%
for epoch in range(20001):
    out = model(X)                      # คิดไปข้างหน้า
    loss = loss_fn(out, y)              # วัดความผิด
    if epoch in (0, 100, 1000, 5000, 20000):
        print(f"รอบ {epoch:5d}  loss = {loss.item():.4f}")
    opt.zero_grad()
    loss.backward()                     # ใบตำหนิย้อนกลับ ในบรรทัดเดียว
    opt.step()                          # ขยับทุกน้ำหนักหนึ่งก้าว

print("คำตอบหลังฝึก", model(X).detach().numpy().round(3).ravel())
# Out:
# รอบ     0  loss = 0.2548
# รอบ   100  loss = 0.2501
# รอบ  1000  loss = 0.2500
# รอบ  5000  loss = 0.0355
# รอบ 20000  loss = 0.0004
# คำตอบหลังฝึก [0.021 0.982 0.982 0.019]
